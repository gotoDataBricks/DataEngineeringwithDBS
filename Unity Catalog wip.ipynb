# %%
dbutils.fs.ls('abfss://datalake@adlsdatabrickssg.dfs.core.windows.net/')

# %%
df=spark.read.csv('abfss://datalake@adlsdatabrickssg.dfs.core.windows.net/Superstore.csv', header=True, inferSchema=True)
display(df)

# %%
spark.sql('describe catalog extended tactical_dev;')

# %%
# %sql
Describe catalog extended tactical_dev

# %%
# %sql
Create catalog stage_dev
comment 'this is the catalog created using sql'

# %%
# %sql
create schema tactical_dev.raw

# %%
# %sql
create table tactical_dev.raw.employee_managed (
empid int,
empname string,
salary double 
);

# %%
# %sql
insert into tactical_dev.raw.employee_managed values (1,'John',100000),(2,'Mary',120000),(3,'Jane',150000)

# %%
# %sql
create table tactical_dev.raw.employee_external (
empid int,
empname string,
salary double 
)
location 'abfss://datalake@adlsdatabrickssg.dfs.core.windows.net/datalake/Ext_tables/emp_external'

# %%
# %sql
insert into tactical_dev.raw.employee_external values (1,'John',100000),(2,'Mary',120000),(3,'Jane',150000)

# %%
# %sql
describe extended tactical_dev.raw.employee_external

# %%
# %sql
describe extended tactical_dev.raw.employee_managed

# %%
# %sql
drop table tactical_dev.raw.employee_managed

# %%
# %sql
select * from tactical_dev.raw.employee_managed

# %%
# %sql
drop table tactical_dev.raw.employee_managed

# %%
# %sql
select * from tactical_dev.raw.employee_managed

# %%
# %sql
use catalog tactical_dev;

show tables dropped in raw

# %%
# %sql
undrop table tactical_dev.raw.employee_managed

# %%
dbutils.fs.ls('abfss://datalake@adlsdatabrickssg.dfs.core.windows.net/')

# %%
dbutils.fs.help()

# %%
dbutils.fs.ls('abfss://datalake@adlsdatabrickssg.dfs.core.windows.net/datalake/Ext_tables/emp_external/')

# %%
path = dbutils.fs.ls('abfss://datalake@adlsdatabrickssg.dfs.core.windows.net/datalake/Ext_tables/emp_external/part-00000-39f9e8de-dcfc-44e7-8b5b-8a4d3816c27c.c000.snappy.parquet')

# %%
# Read the data into a Spark DataFrame
df = spark.read.format("parquet").load('abfss://datalake@adlsdatabrickssg.dfs.core.windows.net/datalake/Ext_tables/emp_external')

# Display details or perform operations
df.show()
df.printSchema()

# %%
df_p = spark.read.format("delta").load('abfss://datalake@adlsdatabrickssg.dfs.core.windows.net/datalake/Ext_tables/emp_external/part-00000-39f9e8de-dcfc-44e7-8b5b-8a4d3816c27c.c000.snappy.parquet')
