-- %% [markdown]
-- ##Extract Address Data

-- %%
Select * from tsv.`/Volumes/ecomm/landing/operational_data_new/addresses/`
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-4970108148643319>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', 'Select * from tsv.`/Volumes/ecomm/landing/operational_data_new/addresses/`\n')
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- ...

-- %%
Select * from csv.`/Volumes/ecomm/landing/operational_data_new/addresses/`
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
Select * from read_files('/Volumes/ecomm/landing/operational_data_new/addresses/', 
                        format => 'csv',
                        delimiter => '\t',
                        header => true);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
create or replace view ecomm.bronze.v_addresses
as 
select * from read_files('/Volumes/ecomm/landing/operational_data_new/addresses/', 
                        format => 'csv',
                        delimiter => '\t',
                        header => true);

-- %%
select * from ecomm.bronze.v_addresses
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
