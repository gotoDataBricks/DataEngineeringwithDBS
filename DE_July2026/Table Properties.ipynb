-- %% [markdown]
-- ### Comments and table properties

-- %%
Drop table if exists ktproject.delta_lake.companies;
create table if not exists ktproject.delta_lake.companies
(
    company_name String,
    founded_date Date,
    country String
)
comment 'This table contains information about companies';

-- %%
desc extended ktproject.delta_lake.companies
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
Drop table if exists ktproject.delta_lake.companies;
create table if not exists ktproject.delta_lake.companies
(
    company_name String,
    founded_date Date,
    country String
)
comment 'This table contains information about companies'
tblproperties ('sensitivite' = 'true');

-- %%
desc extended ktproject.delta_lake.companies
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
Drop table if exists ktproject.delta_lake.companies;
create table if not exists ktproject.delta_lake.companies
(
    company_name String,
    founded_date Date,
    country String
)
comment 'This table contains information about companies'
tblproperties ('sensitivite' = 'true', 'delta.enabledeletionvectors' = 'false')
;

-- %%
alter table ktproject.delta_lake.companies 

set tblproperties ('delta.logretentionduration' = 'interval 30 days')

-- %%
desc extended ktproject.delta_lake.companies
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ## Column Properties

-- %%
Drop table if exists ktproject.delta_lake.companies;
create table if not exists ktproject.delta_lake.companies
(
    company_name String not null,
    founded_date Date comment 'This is the date the company was founded',
    country String
)
comment 'This table contains information about companies'
tblproperties ('sensitivite' = 'true');

-- %%
desc extended ktproject.delta_lake.companies
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ## Generated Identity Columns

-- %%
Drop table if exists ktproject.delta_lake.companies;
create table if not exists ktproject.delta_lake.companies
(
    company_id bigint not null Generated always as identity (start with 1000 increment by 1),
    company_name String not null,
    founded_date Date comment 'This is the date the company was founded',
    country String
)
comment 'This table contains information about companies'
tblproperties ('sensitivite' = 'true');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
insert into ktproject.delta_lake.companies
(company_name, founded_date, country)
values
('Microsoft', '1975-04-04', 'USA'),
('Google', '1998-09-04', 'USA'),
('Amazon', '1994-05-05', 'USA'),
('Alibaba', '1999-07-01', 'China')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>4</td><td>4</td></tr></tbody></table></div>

-- %%
select * from ktproject.delta_lake.companies
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>company_id</th><th>company_name</th><th>founded_date</th><th>country</th></tr></thead><tbody><tr><td>1000</td><td>Microsoft</td><td>1975-04-04</td><td>USA</td></tr><tr><td>1001</td><td>Google</td><td>1998-09-04</td><td>USA</td></tr><tr><td>1002</td><td>Amazon</td><td>1994-05-05</td><td>USA</td></tr><tr><td>1003</td><td>Alibaba</td><td>1999-07-01</td><td>China</td></tr></tbody></table></div>

-- %%
Drop table if exists ktproject.delta_lake.companies;
create table if not exists ktproject.delta_lake.companies
(
    company_id bigint not null Generated always as identity (start with 1000 increment by 1),
    company_name String not null,
    founded_date Date comment 'This is the date the company was founded',
    founded_year int generated always as (year(founded_date)),
    country String
)
comment 'This table contains information about companies'
tblproperties ('sensitivite' = 'true');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
insert into ktproject.delta_lake.companies
(company_name, founded_date, country)
values
('Microsoft', '1975-04-04', 'USA'),
('Google', '1998-09-04', 'USA'),
('Amazon', '1994-05-05', 'USA'),
('Alibaba', '1999-07-01', 'China')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>4</td><td>4</td></tr></tbody></table></div>

-- %%
select * from ktproject.delta_lake.companies
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>company_id</th><th>company_name</th><th>founded_date</th><th>founded_year</th><th>country</th></tr></thead><tbody><tr><td>1000</td><td>Microsoft</td><td>1975-04-04</td><td>1975</td><td>USA</td></tr><tr><td>1001</td><td>Google</td><td>1998-09-04</td><td>1998</td><td>USA</td></tr><tr><td>1002</td><td>Amazon</td><td>1994-05-05</td><td>1994</td><td>USA</td></tr><tr><td>1003</td><td>Alibaba</td><td>1999-07-01</td><td>1999</td><td>China</td></tr></tbody></table></div>
